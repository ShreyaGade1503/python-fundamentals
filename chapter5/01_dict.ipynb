# %%
marks = { 
    "Riya" : 100,               # Dictonary is Mutable
    "Ram" : 56,
    "Harry" : 23
}

print(marks)

print(marks["Harry"])

marks["Riya"]
# Out:
# {'Riya': 100, 'Ram': 56, 'Harry': 23}
# 23
# 100
