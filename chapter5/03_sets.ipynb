# %%
s = {1,2,3,4,5}

e = set() # Dont use s = {} as it will create a dictonary not a set

# %%
s = { 1, 5, 32 , 54 , 5, 6, 5 }   # Set is Unordered and Unindexed and does not allow duplicate values

print(s)
# Out:
# {32, 1, 5, 6, 54}
