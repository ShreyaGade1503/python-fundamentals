# %% [markdown]
# 1. Write a program to create a dictionary of Hindi words with values as their English
# translation. Provide user with an option to look it up!

# %%
dict = {
    "Madad" : "Help",
    "Kursi" : "Chair",
    "Billi" : "Cat",
    "Kutta" : "Dog"
    }

word = input("Enter the word you want to meaning of :")

print(dict[word])
# Out:
# Dog

# %% [markdown]
# 2. Write a program to input eight numbers from the user and display all the unique numbers
# (once).

# %%
s = set()

n = int(input("Enter the number 1 :"))
s.add(n)
n = int(input("Enter the number 1 :"))
s.add(n)
n = int(input("Enter the number 1 :"))
s.add(n)
n = int(input("Enter the number 1 :"))
s.add(n)
n = int(input("Enter the number 1 :"))
s.add(n)
n = int(input("Enter the number 1 :"))
s.add(n)
n = int(input("Enter the number 1 :"))
s.add(n)
n = int(input("Enter the number 1 :"))
s.add(n)

print(s)
# Out:
# {1, 2, 4, 5, 6}

# %% [markdown]
# 3. Can we have a set with 18 (int) and '18' (str) as a value in it?

# %%
s = set()

s.add(18)
s.add("18")

print(s)
# Out:
# {18, '18'}

# %% [markdown]
# 4. What will be the length of following set s:
#
# s = set()
# s.add(20)
# s.add(20.0)
# s.add('20') # length of s after these operations?

# %%
s = set()

s.add(20)
s.add(20.0)
s.add('20')

print(s)
print(len(s))
# Out:
# {'20', 20}
# 2

# %% [markdown]
# 5. s = {}
# What is the type of 's'?

# %% [markdown]
# s = {} is an Empty Dictonary

# %% [markdown]
# 6. Create an empty dictionary. Allow 4 friends to enter their favorite language as value and
# use key as their names. Assume that the names are unique.

# %%
d = {} 

name = input("Enter the name :")
lang = input("Enter the language name :")

d.update({name : lang})
name = input("Enter the name :")
lang = input("Enter the language name :")

d.update({name : lang})
name = input("Enter the name :")
lang = input("Enter the language name :")

d.update({name : lang})
name = input("Enter the name :")
lang = input("Enter the language name :")

d.update({name : lang})

print(d)
# Out:
# {'sam': 'pyhton', 'shrey': 'cpp', 'rohan': 'java', 'divya ': 'cpp'}

# %% [markdown]
# 7. If the names of 2 friends are same; what will happen to the program in problem 6?

# %% [markdown]
# It value entered later will updated
#
# Ex., name is "Rohan" and value is python
#     again the name is "Rohan" and the value is java
#
# Then, it will update "Rohan" : "Python"  TO "Rohan" : "Java"

# %% [markdown]
# 8. If languages of two friends are same; what will happen to the program in problem 6?

# %% [markdown]
# Nothing will happen the values can be same

# %% [markdown]
# 9. Can you change the values inside a list which is contained in set S?
# s = {8, 7, 12, "Harry", [1,2]}

# %%
s = {8, 7, 12, "Harry", (1,2)}

# NO , we cannot add list in set because list is mutable and set is immutable.
