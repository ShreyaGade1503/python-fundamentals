# %%
s = { 1, 5, 32 , 54 , 5, 6, 5 }   

print(s, type(s))
# Out:
# {32, 1, 5, 6, 54} <class 'set'>

# %%
s.add(45)

print(s, type(s))
s.remove(1)
print(s, type(s))
# Out:
# {32, 1, 5, 6, 54, 45} <class 'set'>
# {32, 5, 6, 54, 45} <class 'set'>
