# %%
name = 'harry' # string is immutable

nameshort = name[0:3] # start from index 0 till 3 (excluding 3)
print(nameshort) 
char1 = name[1]
print(char1)
# Out:
# har
# a

# %%
print(name[0:3])
print(name[1:3])
# Out:
# har
# ar
