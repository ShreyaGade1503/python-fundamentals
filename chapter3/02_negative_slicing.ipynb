# %%
name = "Harry"

print(name[0:3])

print(name[-4:-1])
print(name[1:4]) # covert to corresponding postive indexes 

print(name[:4])  # is same as print(name[0:4])
print(name[1:])  #  is same as print(name[1:5])
print(name[1:5])
# Out:
# Har
# arr
# arr
# Harr
# arry
# arry
