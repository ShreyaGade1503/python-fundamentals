# %%
a = (1,2,3,4,5)

print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
a = (1,) # for single element tuple we have to put comma after the element

print(type(a))
# Out:
# <class 'tuple'>

# %%
a = (1,45,323,3224,False,"Rohan","Shivam")
print(a[3])
# Out:
# 3224
