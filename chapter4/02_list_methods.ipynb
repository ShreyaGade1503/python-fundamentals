# %%
frineds = ["apple","Orange",5,35.06,False,"Akash","Rohan"]

print(frineds)

frineds.append("Harry")
print(frineds)
# Out:
# ['apple', 'Orange', 5, 35.06, False, 'Akash', 'Rohan']
# ['apple', 'Orange', 5, 35.06, False, 'Akash', 'Rohan', 'Harry']

# %%
l1 = [342,546,1,28,76,3,5,0,8,7,53,12]

l1.sort()
print(l1)

l1.reverse()
print(l1)

l1.insert(2,"4010")
print(l1)

print(l1.pop(3))
# Out:
# [0, 1, 3, 5, 7, 8, 12, 28, 53, 76, 342, 546]
# [546, 342, 76, 53, 28, 12, 8, 7, 5, 3, 1, 0]
# [546, 342, '4010', 76, 53, 28, 12, 8, 7, 5, 3, 1, 0]
# 76

# %%
print(l1.remove(5))
print(l1)
# Out:
# None
# [546, 342, '4010', 53, 28, 8, 7, 3, 1, 0]
