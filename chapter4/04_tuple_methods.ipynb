# %%
a = (1,45,323,3224,False,"Rohan",45,"Shivam") 
# tuplesare immutable
print(a)
# Out:
# (1, 45, 323, 3224, False, 'Rohan', 45, 'Shivam')

# %%
no = a.count(45)
print(no)
# Out:
# 2

# %%
i = a.index("Rohan")
print(i)
# Out:
# 5

# %%
print(len(a))
# Out:
# 8
