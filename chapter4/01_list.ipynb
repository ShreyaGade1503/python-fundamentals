# %%
frineds = ["apple","Orange",5,35.06,False,"Akash","Rohan"]
# lista are mutable
print(frineds[3])

frineds[0] = "Mango"
print(frineds[0])

print(frineds[1:4])
# Out:
# 35.06
# Mango
# ['Orange', 5, 35.06]
