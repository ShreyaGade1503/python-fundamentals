# %% [markdown]
# 1. Write a program to read the text from a given file ‘poems.txt’ and find out whether it
# contains the word ‘twinkle’.

# %%
f = open("poem.txt")

c = f.read()

if("Twinkle" in c ):
    print("Twinkle is present in the poem")
else:
    print("Twinkle is not present in the poem")
# Out:
# Twinkle is present in the poem

# %% [markdown]
# 2. The game() function in a program lets a user play a game and returns the score as an
# integer. You need to read a file ‘Hi-score.txt’ which is either blank or contains the previous
# Hi-score. You need to write a program to update the Hi-score whenever the game()
# function breaks the Hi-score.

# %%
import random

def game():
    print("You are playing the game now...")
    score = random.randint(1 , 100)

    # fetch the high_score

    with open("highscore.txt") as f:
        high_score = f.read()
        if(high_score != ""):
            high_score = int(high_score)
        else:
            high_score = 0

    print(f"Your Score is : {score}")

    if(score > high_score):
        #write this score to the file
        with open("highscore.txt" , "w" ) as f:
            f.write(str(score))

game()
# Out:
# You are playing the game now...
# Your Score is : 87

# %% [markdown]
# 3. Write a program to generate multiplication tables from 2 to 20 and write it to the different
# files. Place these files in a folder for a 13-year-old.

# %%
def generateTable(n):
    table = ""
    for i in range(1 , 11):
        table += f"{n} x {i} = {n*i}\n"

    with open(f"tables/table_{n}.txt" , "w") as f:
        f.write(table)

for i in range(2, 21):
    generateTable(i)

# %% [markdown]
# 4. A file contains a word “Donkey” multiple times. You need to write a program which
# replaces this word with ##### by updating the same file.

# %%
word = "Donkey"

with open("fileD.txt", "r")as f:
    c = f.read()

cNew = c.replace(word, "#######")

with open("fileD.txt", "w") as f:
    f.write(cNew)

# %% [markdown]
# 5. Repeat program 4 for a list of such words to be censored.

# %%
words = ["Donkey","bad","stupid","idiot"]

with open("fileD.txt", "r")as f:
    c = f.read()

for word in words:
    c = c.replace(word, "!" * len(word))

with open("fileD.txt", "w") as f:
    f.write(c)

# %% [markdown]
# 6. Write a program to mine a log file and find out whether it contains ‘python’.

# %%
with open("log.txt") as f:
    content = f.read()

if("python" in content):
    print("python is present in the file")
else:
    print("python is not present in the file")
# Out:
# python is present in the file

# %% [markdown]
# 7. Write a program to find out the line number where python is present from ques 6.

# %%
with open("log.txt") as f:
    lines = f.readlines()

lineno = 1
for line in lines:
    if("python" in line):
        print("python is present line no : ", lineno)
        break
    lineno += 1
else:
    print("python is not present in the file")
# Out:
# python is present line no :  2

# %% [markdown]
# 8. Write a program to make a copy of a text file “this.txt”.

# %%
with open("this.txt")as f:
    content = f.read()

with open("this_copy.txt", "w") as f:
    f.write(content)

# %% [markdown]
# 9. Write a program to find out whether a file is identical and matches the content of another
# file.

# %%
with open("file.txt")as f:
    content1 = f.read()

with open("poem.txt")as f:
    content2 = f.read()

if(content1 == content2):
    print("The contents of both files are identical.")
else:
    print("NO! The contents of the files are different.")
# Out:
# NO! The contents of the files are different.

# %% [markdown]
# 10. Write a program to wipe out the content of a file using python.

# %%
with open("this_copy.txt" , "w")as f:
    f.write(" ")

# %% [markdown]
# 11. Write a python program to rename a file to “renamed_by_python.txt”.

# %%
with open("old.txt")as f:
    content = f.read()

with open("renamed.txt" , "w")as f:
    f.write(content)
