# %%
l = [1,2,3,4,5,6]

for i in l :
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
t = (34,5,72,4,9705)

for i in t:
    print(i)
# Out:
# 34
# 5
# 72
# 4
# 9705

# %%
s = "Harry"

for i in s :
    print(i)
# Out:
# H
# a
# r
# r
# y
