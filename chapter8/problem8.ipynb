# %% [markdown]
# 1. Write a program using functions to find greatest of three numbers.

# %%
def gretest(a,b,c):
    if a>b and a>c:
        return a
    elif b>a and b>c:
        return b
    else:
        return c
    
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

gretest(a,b,c)
# Out:
# 5

# %% [markdown]
# 2. Write a python program using function to convert Celsius to Fahrenheit.

# %%
def temp(c):
    
    f = c * 9/5 + 32
    print(f"Temperature in Fahrenheit: {f}")

temp(25)
# Out:
# Temperature in Fahrenheit: 77.0

# %% [markdown]
# 3. How do you prevent a python print() function to print a new line at the end.

# %%
print("a")
print("b")
print("c", end="")
print("d")
# Out:
# a
# b
# cd

# %% [markdown]
# 4. Write a recursive function to calculate the sum of first n natural numbers.

# %%
def sumof(n):
    if n == 0 :
        return 0
    return n + sumof(n-1)

n = int(input("Enter a number: "))
sumof(n)
# Out:
# 1

# %% [markdown]
# 5. Write a python function to print first n lines of the following pattern.
# ***
# **
# *

# %%
def pattern(n):
    if n==0:
        return
    print("*" * n)
    pattern(n-1)

pattern(3)
# Out:
# ***
# **
# *

# %% [markdown]
# 6. Write a python function which converts inches to cms.

# %%
def i_to_cms(inch):
    return inch * 2.54

n = float(input("Enter length in inches: "))

print(f"Length in centimeters: {i_to_cms(n)}")
# Out:
# Length in centimeters: 20.32

# %% [markdown]
# 7. Write a python function to remove a given word from a list and strip it at the same time.

# %%
l = ["Shreya","Rohan","Priya","Amit"]

def rem(l,word):
    for i in l:
        l.remove(word)
        return l
    
print(rem(l,"Rohan"))
# Out:
# ['Shreya', 'Priya', 'Amit']

# %% [markdown]
# 8. Write a python function to print multiplication table of a given number.

# %%
def table(n):
    for i in range(1,11):
        print( n ,"*", i ,"=" , n*i)

n = int(input("Enter a number: "))
table(n)
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
