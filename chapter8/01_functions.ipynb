# %%
a  = 12
b = 45
c = 56

avg = ( a + b + c ) / 3
print("The average of a, b and c is: ", avg)
# Out:
# The average of a, b and c is:  37.666666666666664

# %%
# Function Definition

def avg():
    a  = int(input("Enter the value of a: "))
    b = int(input("Enter the value of b: "))
    c = int(input("Enter the value of c: "))

    avg = ( a + b + c ) / 3
    print("The average of a, b and c is: ", int(avg))

# %%
# Function Call

avg()
# Out:
# The average of a, b and c is:  36
