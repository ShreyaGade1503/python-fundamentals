# %%
def goodday(name,end):
    print("GOOD DAY, " + name + end)

goodday("Sam"," thank you")

goodday("Sahil"," thanks")
# Out:
# GOOD DAY, Sam thank you
# GOOD DAY, Sahil thanks

# %%
def goodday(name,end):
    print("Good Day, " + name)
    print(end)
    return "done"

a = goodday("Sam"," thank you")
print(a)
# Out:
# Good Day, Sam
#  thank you
# done
