# %%
a = 31
t = type(a) # class <int>

print(t)
# Out:
# <class 'int'>

# %%
a = 31
b = float(a) # Convert the int to a float
c = str(a) # Convert the int to a string

t = type(a) # class <int>

print(t) 
print(b)
print(c)
# Out:
# <class 'int'>
# 31.0
# 31
