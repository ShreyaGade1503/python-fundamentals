# %%
a = int(input("Enter a number 1 : "))
b = int(input("Enter a number 2 : "))

print("Number 1 is ",a)
print("Number 2 is ",b)

print("Sum is ",a + b)
# Out:
# Number 1 is  3
# Number 2 is  2
# Sum is  5
