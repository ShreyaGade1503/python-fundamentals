# %% [markdown]
# 1. Write a python program to add two numbers.

# %%
a = 110
b = 50

print(a + b)
# Out:
# 160

# %% [markdown]
# 2. Write a python program to find remainder when a number is divided by z.

# %%
a = 34
b = 5

print("remainder when a is divided by b ", a % b)
# Out:
# remainder when a is divided by b  4

# %% [markdown]
# 3. Check the type of variable assigned using input() function.

# %%
var = input("Enter something : ")
t = type(var)
print(t)
# Out:
# <class 'str'>

# %% [markdown]
# 4. Use comparison operator to find out whether ‘a’ given variable is greater than ‘b’ or not.
# Take a = 34 and b = 80

# %%
a = 34
b = 80

result = a>b 
print("a is greater than b is  ",result)
# Out:
# a is greater than b is   False

# %% [markdown]
# 5. Write a python program to find an average of two numbers entered by the user.

# %%
a =  int(input("Enter a number 1 :"))
b =  int(input("Enter a number 2 :"))   

print("Average of A and B are : ", (a+b)/2)
# Out:
# Average of A and B are :  2.0

# %% [markdown]
# 6. Write a python program to calculate the square of a number entered by the user.

# %%
num = int(input("Enter a number : "))
print("Number is : ",num)
print("Square of the number is : ", num * num)
print("Square of the number is : ", num ** 2)
# print("Square of the number is : ", num^2) # incorrect for finding square
# Out:
# Number is :  5
# Square of the number is :  25
# Square of the number is :  25
